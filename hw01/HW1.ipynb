# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
img = mpimg.imread('beach1.jpg')
plt.imshow(img)

# %%
img.shape
# Out:
# (183, 275, 3)

# %%
green_image = img.copy() # Make a copy
green_image[:,:,0] = 0
green_image[:,:,2] = 0 
plt.imshow(green_image)

# %%
blue_image = img.copy() # Make a copy
blue_image[:,:,0] = 0
blue_image[:,:,1] = 0
plt.imshow(blue_image)

# %%
yellow_image = img.copy() # Make a copy
yellow_image[:,:,2] = 0
plt.imshow(yellow_image)
